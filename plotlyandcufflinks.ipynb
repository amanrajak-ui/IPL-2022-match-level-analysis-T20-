# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in d:\anaconda\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in d:\anaconda\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from plotly) (24.2)

# %%
# !pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in d:\anaconda\lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in d:\anaconda\lib\site-packages (from cufflinks) (2.1.3)
# Requirement already satisfied: pandas>=0.19.2 in d:\anaconda\lib\site-packages (from cufflinks) (2.2.3)
# Requirement already satisfied: plotly>=4.1.1 in d:\anaconda\lib\site-packages (from cufflinks) (5.24.1)
# Requirement already satisfied: six>=1.9.0 in d:\anaconda\lib\site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in d:\anaconda\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in d:\anaconda\lib\site-packages (from cufflinks) (72.1.0)
# Requirement already satisfied: ipython>=5.3.0 in d:\anaconda\lib\site-packages (from cufflinks) (8.30.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in d:\anaconda\lib\site-packages (from cufflinks) (8.1.5)
# Requirement already satisfied: decorator in d:\anaconda\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\anaconda\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\anaconda\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.19.1)
# Requirement already satisfied: stack-data in d:\anaconda\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in d:\anaconda\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: wcwidth in d:\anaconda\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: comm>=0.1.3 in d:\anaconda\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in d:\anaconda\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.13)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in d:\anaconda\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\anaconda\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=0.19.2->cufflinks) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in d:\anaconda\lib\site-packages (from plotly>=4.1.1->cufflinks) (9.0.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from plotly>=4.1.1->cufflinks) (24.2)
# Requirement already satisfied: executing in d:\anaconda\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (3.0.0)
# Requirement already satisfied: pure-eval in d:\anaconda\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.2)

# %%
import seaborn as sns
import pandas as pd 
import cufflinks as cf 
from plotly.offline import iplot

# %%
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
