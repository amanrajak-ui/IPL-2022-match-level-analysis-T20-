# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib Basics

# %%
x=np.linspace(0,5,11)
x
y=x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(x,y)
plt.title("Hello")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# Subplots in Matplotlib-ek sath multiple plot banana ho to

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)

# %% [markdown]
# Object Oriented way
#
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize=(12,8),dpi=100)
axis1=fig.add_axes([0.1,0.1,0.4,.4])
axis1.plot(x,y)
axis1.set_title("main plot",fontsize=10)
axis2=fig.add_axes([0.3,0.4,0.3,0.3])
axis2.plot(x,y,color='red')
axis2.set_title("2nd plot")
# Out:
# Text(0.5, 1.0, '2nd plot')

# %% [markdown]
# Types of Plots

# %%
plt.scatter(x,y,color='red')

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([11., 13., 11., 10.,  4., 17., 15.,  9.,  4.,  6.]),
#  array([  3. , 101.7, 200.4, 299.1, 397.8, 496.5, 595.2, 693.9, 792.6,
#         891.3, 990. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24f0e9f7d90>,
#   <matplotlib.lines.Line2D at 0x24f0e9f7ed0>],
#  'caps': [<matplotlib.lines.Line2D at 0x24f0ea34050>,
#   <matplotlib.lines.Line2D at 0x24f0ea34190>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24f0e9f7c50>],
#  'medians': [<matplotlib.lines.Line2D at 0x24f0ea342d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24f0ea34410>],
#  'means': []}

# %% [markdown]
# Saving Plots

# %%
fig = plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("basicplot.png")

# %% [markdown]
# Working with Images

# %%
import matplotlib.image as mpimg

# %%
# img = mpimg.imread('p.jpg')
# plt.imshow(img)
# plt.axis('off')

# %%
cropped_img=img[10:50,10:100]
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(89.5), np.float64(39.5), np.float64(-0.5))

# %% [markdown]
# optional designing

# %%
plt.plot(x,y,color='pink')

# %%
xaxis=np.linspace(0,5,11)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
